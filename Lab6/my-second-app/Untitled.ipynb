# %% [raw]
# # Heading 1
# # Heading 1
# # Heading 1
# # Heading 1

# %% [markdown]
# # Heading 1

# %%
Heading 1
# Out:
#   Input In [1]
#     Heading 1
#             ^
# SyntaxError: invalid syntax
