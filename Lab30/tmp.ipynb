# %%
def foo(n):
    total = 0
    for num in range(n):
        total+=num

    print(total)


# %timeit foo(10_000)
# Out:
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# 49995000
# ...
