# %% [markdown]
# <a href="https://colab.research.google.com/github/geekcourses/ML_SA_Labs/blob/1_ML_SA/JupyterNotebookTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Jupyter Notebook Demo

# %% [markdown]
# ## Keyboard Shortcuts

# %% [markdown]
# ### Notes for Colab
#
# Use prefix CTRL+M

# %% [markdown]
# ### Execute cell
# 1. Alt+Enter: Run cell and insert new cell
# 1. Shift+Enter: Run cell and select next cell
# 1. Ctrl+Enter: Run the focused cell

# %% [markdown]
# ## Python Code demos

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.arange(1,10)
Y = X**2

# %%
print(X)
print(Y)
# Out:
# [1 2 3 4 5 6 7 8 9]
# [ 1  4  9 16 25 36 49 64 81]

# %%
plt.scatter(X, Y)
