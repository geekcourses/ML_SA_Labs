# %%
import pandas as pd

# %%
data_csv_path = 'https://raw.githubusercontent.com/geekcourses/JupyterNotebooksExamples/master/datasets/various/drinks.csv'
df = pd.read_csv(data_csv_path)
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
df.shape
# Out:
# (193, 6)

# %%
# df.describe().iloc[-1,2]
# df.describe().loc['max','wine_servings']
df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
# get all rows with NaN in continent
df[df['continent'].isna()]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# ...

# %%
# fill NaN in Continent with 'Unknown'

# df['continent'].fillna('Unknown', inplace=True)
# df.head(10)

# %%
df.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# ...

# %%
# df[column_label]
# gdf[['country', 'continent']]
new_data = df['continent'].fillna('Unknown')
# df['fill_continent'] = new_data

# insert at specified pos
if not 'fill_continent' in df.columns:
    df.insert(1, 'fill_continent',new_data)

df.head(10)
# Out:
#              country fill_continent  beer_servings  spirit_servings  \
# 0        Afghanistan             AS              0                0
# 1            Albania             EU             89              132
# 2            Algeria             AF             25                0
# 3            Andorra             EU            245              138
# 4             Angola             AF            217               57
# 5  Antigua & Barbuda        Unknown            102              128
# 6          Argentina             SA            193               25
# 7            Armenia             EU             21              179
# 8          Australia             OC            261               72
# 9            Austria             EU            279               75
#
#    wine_servings  total_litres_of_pure_alcohol continent
# 0              0                           0.0        AS
# 1             54                           4.9        EU
# ...

# %%
# drop row:
df.drop(labels=0, inplace=True)

# %%
df.head(5)
# Out:
#              country fill_continent  beer_servings  spirit_servings  \
# 1            Albania             EU             89              132
# 2            Algeria             AF             25                0
# 3            Andorra             EU            245              138
# 4             Angola             AF            217               57
# 5  Antigua & Barbuda        Unknown            102              128
#
#    wine_servings  total_litres_of_pure_alcohol continent
# 1             54                           4.9        EU
# 2             14                           0.7        AF
# 3            312                          12.4        EU
# 4             45                           5.9        AF
# 5             45                           4.9       NaN

# %%
print(new_df)
# Out:
# None
