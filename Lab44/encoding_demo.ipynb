# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
# Create DataFrame
df = pd.DataFrame({'Color': ['Red', 'Blue', 'Green', 'Blue', 'Red']})
df
# Out:
#    Color
# 0    Red
# 1   Blue
# 2  Green
# 3   Blue
# 4    Red

# %%
# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# Apply the encoder
df['Color LE Encoded'] = label_encoder.fit_transform(df['Color'])

# Display the encoded DataFrame
df
# Out:
#    Color  Color LE Encoded
# 0    Red                 2
# 1   Blue                 0
# 2  Green                 1
# 3   Blue                 0
# 4    Red                 2

# %%
# Create One-Hot Encoding instance
one_hot_encoder = OneHotEncoder(sparse_output=False)

# Apply the encoder
encoded_color = pd.DataFrame(
    one_hot_encoder.fit_transform(df[['Color']]),
    columns=one_hot_encoder.get_feature_names_out(['Color'])
)

pd.concat([df, encoded_color], axis=1)
# Out:
#    Color  Color LE Encoded  Color_Blue  Color_Green  Color_Red
# 0    Red                 2         0.0          0.0        1.0
# 1   Blue                 0         1.0          0.0        0.0
# 2  Green                 1         0.0          1.0        0.0
# 3   Blue                 0         1.0          0.0        0.0
# 4    Red                 2         0.0          0.0        1.0
