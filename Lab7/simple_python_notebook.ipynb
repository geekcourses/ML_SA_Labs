# %%
print(1)
print(2)
print(2)
print(2)
print(2)
print(2)
# here, Python will rise error and stops
print(iva)
print(3)
print(3)
# Out:
# 1
# 2
# 2
# 2
# 2
# 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /media/nemsys/data/projects/courses/netIT/ML_SA/ML_SA_Labs/Lab7/simple_python_notebook.ipynb Cell 1' in <cell line: 8>()
#       <a href='vscode-notebook-cell:/media/nemsys/data/projects/courses/netIT/ML_SA/ML_SA_Labs/Lab7/simple_python_notebook.ipynb#ch0000000?line=5'>6</a> print(2)
#       <a href='vscode-notebook-cell:/media/nemsys/data/projects/courses/netIT/ML_SA/ML_SA_Labs/Lab7/simple_python_notebook.ipynb#ch0000000?line=6'>7</a> # here, Python will rise error
# ----> <a href='vscode-notebook-cell:/media/nemsys/data/projects/courses/netIT/ML_SA/ML_SA_Labs/Lab7/simple_python_notebook.ipynb#ch0000000?line=7'>8</a> print(iva)
#       <a href='vscode-notebook-cell:/media/nemsys/data/projects/courses/netIT/ML_SA/ML_SA_Labs/Lab7/simple_python_notebook.ipynb#ch0000000?line=8'>9</a> print(3)
# ...

# %%
x = 2

if x>0:
    print('Положително число')
    print(1)
# Out:
# Положително число
# 1

# %%
print(1)
print(1)
# Out:
# 1
# 1

# %% [markdown]
# Пример, за грешка при смесване на табове и спейсове

# %%
x = 8

if x>0:
	print("+" * 5)
    print("Positive")
else:
	print("-"*5)
	print("negative")
# Out:
#   File <tokenize>:5
#     print("Positive")
#     ^
# IndentationError: unindent does not match any outer indentation level
