# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# y1 = 1.5x + 1
# y2 = 3x + 1

# Define the slope (m) and intercept (b)
m1 = 1.5
b1 = 1

m2 = 3
b2 = 1

# %%
# Generate x values
X = np.linspace(-10, 10, 100)

# Calculate y values based on the slope-intercept form
Y1 = m1 * X + b1
Y2 = m2 * X + b2

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharey=True)
ax1.plot(X,Y1, label=f' {m1} * X + {b1}')
ax2.plot(X,Y2, label=f' {m2} * X + {b2}')

# add auxiliary lines
# horizontal line (y=0)
ax1.axhline(0, color='black',linewidth=0.5)
# vertical line (x=0)
ax1.axvline(0, color='black',linewidth=0.5)

ax1.axhline(b, color='red', linestyle='--', linewidth=1)
ax1.axvline(m, color='green', linestyle='--',linewidth=1)

ax1.legend()
ax1.grid()
ax2.grid()
